# %% [markdown]
# ## One Qubit Gate - Pauli gates
# (revised by Amba Datt Pant, originaly created by Diwakar Sigdel)

# %%
from qiskit import *
from math import pi
from qiskit.visualization import plot_bloch_multivector

# %% [markdown]
# ## Single-Qubit Gates
#
# The single-qubit gates available are:
# - u gates
# - Identity gate
# - Pauli gates
# - Clifford gates
# - $C3$ gates
# - Standard rotation gates
#
# We have provided a backend: `unitary_simulator` to allow you to calculate the unitary matrices.

# %% [markdown]
# -------

# %% [markdown]
# - states of qubits represented by 2D vectors, ![image.png](attachment:image.png) \theta and \phi are real numbers

# %% [markdown]
# ### Pauli gates
#
# #### $X$: bit-flip gate
#
# The bit-flip gate $X$ is defined as:
#
# $$
# X   =
# \begin{pmatrix}
# 0 & 1\\
# 1 & 0
# \end{pmatrix}= u3(\pi,0,\pi)
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
# https://qiskit.org/textbook/ch-states/single-qubit-gates.html

# %%
# Let's do an X-gate on a |0> qubit
qc = QuantumCircuit(1)
qc.x(0)
qc.draw('mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
print(out)
plot_bloch_multivector(out)
# Out:
# [0.+0.j 1.+0.j]

# %%
# Run the quantum circuit on a unitary simulator backend
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()

# Show the results
print(result.get_unitary(qc, decimals=3))

# get_unitary(experiment=None, decimals=None)
# Get the final unitary of an experiment.
# Out:
# [[ 0.-0.j  0.-0.j  0.-0.j  0.-1.j  0.-0.j  0.-0.j  0.-0.j  0.-0.j]
#  [ 0.-0.j  0.-0.j  0.-1.j  0.-0.j  0.-0.j  0.-0.j  0.-0.j  0.-0.j]
#  [ 0.+0.j  0.+1.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+1.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+1.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+1.j  0.+0.j]
#  [-0.+0.j -0.+0.j -0.+0.j -0.+0.j -0.+0.j -0.-1.j -0.+0.j -0.+0.j]
#  [-0.+0.j -0.+0.j -0.+0.j -0.+0.j -0.-1.j -0.+0.j -0.+0.j -0.+0.j]]

# %% [markdown]
# Methods of Result class \ https://qiskit.org/documentation/stubs/qiskit.result.Result.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### $Y$: bit- and phase-flip gate
#
# The $Y$ gate is defined as:
#
# $$
# Y  =
# \begin{pmatrix}
# 0 & -i\\
# i & 0
# \end{pmatrix}=u3(\pi,\pi/2,\pi/2)
# $$

# %% [markdown]
# https://qiskit.org/textbook/ch-states/single-qubit-gates.html
# ![image.png](attachment:image.png)

# %%
# Let's do an X-gate on a |0> qubit
qc = QuantumCircuit(1)
qc.y(0)                     # y(n_q) -> y gate at qubit indexed n_q
qc.draw('mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
print(out)
plot_bloch_multivector(out)
# Out:
# [0.-0.j 0.+1.j]

# %%
# Run the quantum circuit on a unitary simulator backend
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
print(out)
result = job.result()

# Show the results
print(result.get_unitary(qc, decimals=3))   # decimal -> number of decimals in statevectors 
# https://qiskit.org/documentation/stubs/qiskit.result.Result.html
# Out:
# [0.-0.j 0.+1.j]
# [[0.-0.j 0.-1.j]
#  [0.+1.j 0.+0.j]]

# %% [markdown]
# #### $Z$: phase-flip gate
#
# The phase flip gate $Z$ is defined as:
#
# $$
# Z =
# \begin{pmatrix}
# 1 & 0\\
# 0 & -1
# \end{pmatrix}=u1(\pi)
# $$

# %%
qc = QuantumCircuit(1)
qc.z(0)
qc.draw(output='mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
print(out)
plot_bloch_multivector(out)
# Out:
# [ 1.+0.j -0.+0.j]

# %%
# Run the quantum circuit on a unitary simulator backend
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
#print(out)
result = job.result()

# Show the results
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 1.+0.j  0.+0.j]
#  [-0.+0.j -1.+0.j]]

# %% [markdown]
# #### Experiment 1:

# %%
# Let's do an X-gate on a |0> qubit
qc = QuantumCircuit(1)
qc.x(0)
qc.x(0)
qc.y(0)
qc.y(0)
qc.z(0)
qc.z(0)
#qc.cx(0)
qc.draw('mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
print(out)
plot_bloch_multivector(out)
# Out:
# [1.-0.j 0.-0.j]

# %%
# Run the quantum circuit on a unitary simulator backend
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()

# Show the results
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.-0.j 0.-0.j]
#  [0.-0.j 1.-0.j]]

# %% [markdown]
# #### Experiment 2:

# %%
# Let's do an X-gate on a |0> qubit
qc = QuantumCircuit(2)
qc.x(0)
qc.y(1)
qc.draw('mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
print(out)
plot_bloch_multivector(out)
# Out:
# [0.-0.j 0.-0.j 0.+0.j 0.+1.j]

# %% [markdown]
# $Y \otimes X$

# %%
# Run the quantum circuit on a unitary simulator backend
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()

# Show the results
print(result.get_unitary(qc, decimals=3))
# Out:
# [[0.-0.j 0.-0.j 0.-0.j 0.-1.j]
#  [0.-0.j 0.-0.j 0.-1.j 0.-0.j]
#  [0.+0.j 0.+1.j 0.+0.j 0.+0.j]
#  [0.+1.j 0.+0.j 0.+0.j 0.+0.j]]

# %% [markdown]
# ---------------

# %%
# Let's do an X-gate on a |0> qubit
qc = QuantumCircuit(2)
qc.x(0)
qc.y(1)
qc.z(0)
qc.x(1)
qc.draw('mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
print(out)
plot_bloch_multivector(out)
# Out:
# [ 0.+0.j -0.-1.j  0.-0.j  0.+0.j]

# %% [markdown]
# $ (X \otimes Z)  \times (Y \otimes X)$

# %%
# Run the quantum circuit on a unitary simulator backend
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()

# Show the results
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 0.+0.j  0.+1.j  0.+0.j  0.+0.j]
#  [-0.-1.j -0.+0.j -0.+0.j -0.+0.j]
#  [ 0.-0.j  0.-0.j  0.-0.j  0.-1.j]
#  [ 0.+0.j  0.+0.j  0.+1.j  0.+0.j]]

# %% [markdown]
# ---------------

# %%
# Let's do an X-gate on a |0> qubit
qc = QuantumCircuit(3)
qc.x(0)
qc.y(1)
qc.z(2)
qc.draw('mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
print(out)
plot_bloch_multivector(out)
# Out:
# [ 0.-0.j  0.-0.j  0.+0.j  0.+1.j  0.+0.j  0.+0.j -0.+0.j -0.+0.j]

# %% [markdown]
# $Z \otimes Y \otimes Z$

# %%
# Run the quantum circuit on a unitary simulator backend
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()

# Show the results
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 0.-0.j  0.-0.j  0.-0.j  0.-1.j  0.-0.j  0.-0.j  0.-0.j  0.-0.j]
#  [ 0.-0.j  0.-0.j  0.-1.j  0.-0.j  0.-0.j  0.-0.j  0.-0.j  0.-0.j]
#  [ 0.+0.j  0.+1.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+1.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+1.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+1.j  0.+0.j]
#  [-0.+0.j -0.+0.j -0.+0.j -0.+0.j -0.+0.j -0.-1.j -0.+0.j -0.+0.j]
#  [-0.+0.j -0.+0.j -0.+0.j -0.+0.j -0.-1.j -0.+0.j -0.+0.j -0.+0.j]]
